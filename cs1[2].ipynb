# %%
import statistics as stats
import matplotlib as mat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
result = pd.read_csv('student_scores.csv')
result.head(20)
# Out:
#     Maths  Physics
# 0      25       21
# 1      51       47
# 2      32       27
# 3      85       75
# 4      35       30
# 5      15       20
# 6      92       88
# 7      55       60
# 8      83       81
# 9      27       25
# 10     77       85
# 11     59       62
# 12     45       41
# 13     33       42
# 14     11       17
# 15     89       95
# 16     25       30
# 17     19       24
# 18     61       67
# 19     74       69

# %%
print(result.shape)
result.describe()
# Out:
# (25, 2)
#            Maths    Physics
# count  25.000000  25.000000
# mean   50.120000  51.480000
# std    25.250941  25.286887
# min    11.000000  17.000000
# 25%    27.000000  30.000000
# 50%    48.000000  47.000000
# 75%    74.000000  75.000000
# max    92.000000  95.000000

# %%
stats.mean(result.Maths)
# Out:
# 50.12

# %%
stats.mean(result.Physics)
# Out:
# 51.48

# %%
stats.median(result.Maths)
# Out:
# 48

# %%
stats.median(result.Physics)
# Out:
# 47

# %%
result.corr() #correlation between two subject result
# Out:
#             Maths   Physics
# Maths    1.000000  0.976191
# Physics  0.976191  1.000000

# %%
print(float(stats.stdev(result.Maths)))
# Out:
# 25.250940576540906

# %%
print(float(stats.stdev(result.Physics)))
# Out:
# 25.286887247478024

# %%
print(float(stats.variance(result.Maths)))
# Out:
# 637.61

# %%
print(float(stats.variance(result.Physics)))
# Out:
# 639.4266666666667

# %%
covariance_Matrix=np.stack((result.Maths,result.Physics),axis=0)
np.cov(covariance_Matrix)
# Out:
# array([[637.61      , 623.315     ],
#        [623.315     , 639.42666667]])

# %%
plt.hist(result.Maths,color='pink',ec='black')
# Out:
# (array([3., 4., 3., 1., 3., 2., 1., 2., 3., 3.]),
#  array([11. , 19.1, 27.2, 35.3, 43.4, 51.5, 59.6, 67.7, 75.8, 83.9, 92. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(result.Physics,color='violet',ec='black')
# Out:
# (array([4., 5., 1., 3., 1., 2., 2., 2., 3., 2.]),
#  array([17. , 24.8, 32.6, 40.4, 48.2, 56. , 63.8, 71.6, 79.4, 87.2, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist([result.Maths,result.Physics])
# Out:
# (array([[3., 4., 3., 1., 3., 3., 1., 3., 2., 2.],
#         [1., 5., 4., 2., 1., 2., 3., 2., 3., 2.]]),
#  array([11. , 19.4, 27.8, 36.2, 44.6, 53. , 61.4, 69.8, 78.2, 86.6, 95. ]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist(result.Maths)
plt.hist(result.Physics)
# Out:
# (array([4., 5., 1., 3., 1., 2., 2., 2., 3., 2.]),
#  array([17. , 24.8, 32.6, 40.4, 48.2, 56. , 63.8, 71.6, 79.4, 87.2, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(result.Maths,result.Physics)

# %%
plt.boxplot(result.Maths)
plt.show()

# %%
plt.boxplot(result.Physics)
plt.show()
